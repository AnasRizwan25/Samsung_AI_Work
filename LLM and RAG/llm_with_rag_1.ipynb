# %% [markdown]
# ## LLM and RAG

# %% [markdown]
# - LLM is a instance of foundation modal.
# - Transformer architecture.
# - LLM basically a (data, architecture, training).
# - Parameters.
# - ML parameters
